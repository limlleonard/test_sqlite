# %%
import sqlite3
from employee import Employee

# %%
lst1=[(8, "Kobe", "Bryant"),
(23, "Lebron", "James"),
(11, "Ming", "Yao")]

# %%
connection = sqlite3.connect('test1.db')
cursor=connection.cursor()
# cursor.execute("create table gta (release_year integer, release_name text, city text)")
# cursor.executemany("insert into gta values (?,?,?)", lst1)

# for row in cursor.execute("select * from gta"):
#   print(row)
cursor.execute("select * from gta where release_year=11")
gta_search = cursor.fetchall()
print(gta_search)

connection.commit()
conn.close()
# Out:
# [(11, 'Ming', 'Yao')]

# %%
# create groery
import sqlite3

groceries = [
  "apples",
  "bananas",
  "clemintines",
  "dill",
  "eggs",
  "flour",
  "granola",
  "honey",
  "ice cream",
  "juice",
  "ketchup",
  "lemon",
  "margarine",
  "onion",
  "potatoes",
  "rosmary",
  "salt",
  "thyme",
  "vinegar",
  "watermelon",
  "pears",
  "cucumbers",
  "garlic",
  "carrots",
  "pastries",
  "eggplants",
  "milk",
  "coffee",
  "tea",
  "rice",
  "noodles",
  "lentils",
  "sweet potatoes",
  "strawberries",
  "cranberries",
  "mangos",
  "pappers",
  "zuccinis",
  "lime",
  "broth",
  "mushrooms",
  "chicken",
  "beef",
  "pork",
  "fish",
  "cream",
  "paprika",
  "tumeric",
  "cinamon",
  "pumpkin",
  "basil",
  "tomatoes",
  "bread",
  "cake",
  "chocolate",
  "gum",
  "pinapple",
  "oranges",
  "lettuce",
  "cheese",
  "cilantro"
]

groceries = sorted(groceries)

connection = sqlite3.connect("grocery_list.db")
cursor = connection.cursor()

cursor.execute("create table groceries (id INTEGER PRIMARY KEY AUTOINCREMENT, name TEXT)")
for i in range(len(groceries)):
  cursor.execute("insert into groceries (name) values (?)",[groceries[i]])
  print("added ", groceries[i])

connection.commit()
connection.close()
# Out:
# added  apples
# added  bananas
# added  basil
# added  beef
# added  bread
# added  broth
# added  cake
# added  carrots
# added  cheese
# added  chicken
# added  chocolate
# added  cilantro
# added  cinamon
# added  clemintines
# added  coffee
# added  cranberries
# added  cream
# added  cucumbers
# added  dill
# added  eggplants
# added  eggs
# added  fish
# added  flour
# added  garlic
# added  granola
# added  gum
# added  honey
# added  ice cream
# added  juice
# added  ketchup
# added  lemon
# added  lentils
# added  lettuce
# added  lime
# added  mangos
# added  margarine
# added  milk
# added  mushrooms
# added  noodles
# added  onion
# added  oranges
# added  pappers
# added  paprika
# added  pastries
# added  pears
# added  pinapple
# added  pork
# added  potatoes
# added  pumpkin
# added  rice
# added  rosmary
# added  salt
# added  strawberries
# added  sweet potatoes
# added  tea
# added  thyme
# added  tomatoes
# added  tumeric
# added  vinegar
# added  watermelon
# added  zuccinis
